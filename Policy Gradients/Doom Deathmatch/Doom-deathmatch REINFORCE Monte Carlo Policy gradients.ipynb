# %% [markdown]
# # Doom-Deathmatch: REINFORCE Monte Carlo Policy gradients 🕹️

# %% [markdown]
# In this notebook we'll implement an agent <b>that try to survive in Doom environment by killing all monster that are spawned in the map.</b> <br>
# Our agent playing after 206 epochs of 1000 batch_size (2h of training with CPU), **we can see that our agent needs much more training but he begins to have rational actions.**
# <img src="assets/doom.gif" alt="Doom Deathmatch" />

# %% [markdown]
# # This is a notebook from [Deep Reinforcement Learning Course with Tensorflow](https://simoninithomas.github.io/Deep_reinforcement_learning_Course/)
# <img src="https://raw.githubusercontent.com/simoninithomas/Deep_reinforcement_learning_Course/master/docs/assets/img/DRLC%20Environments.png" alt="Deep Reinforcement Course"/>
# <br>
# <p>  Deep Reinforcement Learning Course is a free series of articles and videos tutorials 🆕 about Deep Reinforcement Learning, where **we'll learn the main algorithms (Q-learning, Deep Q Nets, Dueling Deep Q Nets, Policy Gradients, A2C, Proximal Policy Gradients…), and how to implement them with Tensorflow.**
# <br><br>
#
# 📜The articles explain the architectures from the big picture to the mathematical details behind them.
# <br>
# 📹 The videos explain how to build the agents with Tensorflow </b></p>
# <br>
# This course will give you a **solid foundation for understanding and implementing the future state of the art algorithms**. And, you'll build a strong professional portfolio by creating **agents that learn to play awesome environments**: Doom© 👹, Space invaders 👾, Outrun, Sonic the Hedgehog©, Michael Jackson’s Moonwalker, agents that will be able to navigate in 3D environments with DeepMindLab (Quake) and able to walk with Mujoco.
# <br><br>
# </p>
#
# ## 📚 The complete [Syllabus HERE](https://simoninithomas.github.io/Deep_reinforcement_learning_Course/)
#
#
# ## Any questions 👨‍💻
# <p> If you have any questions, feel free to ask me: </p>
# <p> 📧: <a href="mailto:hello@simoninithomas.com">hello@simoninithomas.com</a>  </p>
# <p> Github: https://github.com/simoninithomas/Deep_reinforcement_learning_Course </p>
# <p> 🌐 : https://simoninithomas.github.io/Deep_reinforcement_learning_Course/ </p>
# <p> Twitter: <a href="https://twitter.com/ThomasSimonini">@ThomasSimonini</a> </p>
# <p> Don't forget to <b> follow me on <a href="https://twitter.com/ThomasSimonini">twitter</a>, <a href="https://github.com/simoninithomas/Deep_reinforcement_learning_Course">github</a> and <a href="https://medium.com/@thomassimonini">Medium</a> to be alerted of the new articles that I publish </b></p>
#
# ## How to help  🙌
# 3 ways:
# - **Clap our articles and like our videos a lot**:Clapping in Medium means that you really like our articles. And the more claps we have, the more our article is shared Liking our videos help them to be much more visible to the deep learning community.
# - **Share and speak about our articles and videos**: By sharing our articles and videos you help us to spread the word.
# - **Improve our notebooks**: if you found a bug or **a better implementation** you can send a pull request.
# <br>
#
# ## Important note 🤔
# <b> You can run it on your computer but it's better to run it on GPU based services</b>, personally I use Microsoft Azure and their Deep Learning Virtual Machine (they offer 170$)
# https://azuremarketplace.microsoft.com/en-us/marketplace/apps/microsoft-ads.dsvm-deep-learning
# <br>
# ⚠️ I don't have any business relations with them. I just loved their excellent customer service.
#
# If you have some troubles to use Microsoft Azure follow the explainations of this excellent article here (without last the part fast.ai): https://medium.com/@manikantayadunanda/setting-up-deeplearning-machine-and-fast-ai-on-azure-a22eb6bd6429

# %% [markdown]
# ## Prerequisites 🏗️
# Before diving on the notebook **you need to understand**:
# - The foundations of Reinforcement learning (MC, TD, Rewards hypothesis...) [Article](https://medium.freecodecamp.org/an-introduction-to-reinforcement-learning-4339519de419)
# - Policy gradients [Article](https://medium.freecodecamp.org/an-introduction-to-policy-gradients-with-cartpole-and-doom-495b5ef2207f)
# - We made a [tutorial video](https://youtu.be/wLTQRuizVyE) where we implement a Policy Gradient agent with Tensorflow that learns to play Doom 👹🔫 in a Deathmatch environment.

# %%
from IPython.display import HTML
HTML('<iframe width="560" height="315" src="https://www.youtube.com/embed/wLTQRuizVyE?showinfo=0" frameborder="0" allow="autoplay; encrypted-media" allowfullscreen></iframe>')
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/wLTQRuizVyE?showinfo=0" frameborder="0" allow="autoplay; encrypted-media" allowfullscreen></iframe>

# %% [markdown]
# ## Step 1: Import the libraries 📚

# %%
import tensorflow as tf      # Deep Learning library
import numpy as np           # Handle matrices
from vizdoom import *        # Doom Environment
import random                # Handling random number generation
import time                  # Handling time calculation
from skimage import transform# Help us to preprocess the frames

from collections import deque# Ordered collection with ends
import matplotlib.pyplot as plt # Display graphs

import warnings # This ignore all the warning messages that are normally printed during the training because of skiimage
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Step 2: Create our environment 🎮
# - Now that we imported the libraries/dependencies, we will create our environment.
# - Doom environment takes:
#     - A `configuration file` that **handle all the options** (size of the frame, possible actions...)
#     - A `scenario file`: that **generates the correct scenario** (in our case basic **but you're invited to try other scenarios**).
# - Note: We have 3 possible actions turn left, turn right, shoot (attack) `[[0,0,1], [1,0,0], [0,1,0]]` so we don't need to do one hot encoding (thanks to <a href="https://stackoverflow.com/users/2237916/silgon">silgon</a> for figuring out.
#
# ### Our environment
# <img src="https://simoninithomas.github.io/Deep_reinforcement_learning_Course/assets/img/video%20projects/vizdoomdeathmatch.png" style="max-width:500px;" alt="Doom health"/>
#
# - The purpose of this scenario is **to teach the agent that killing the monsters is GOOD and when monsters kill you is BAD**.
# - In addition, **wasting amunition is not very good either**.
# - Agent is rewarded only for killing monsters so he has to figure out the rest for himself.
# <br><br>
# - Map is a large circle. Player is spawned in the exact center. 5 melee-only, monsters are spawned along the wall.
# - **Monsters are killed after a single shot.**
# - After dying each monster is **respawned after some time**.
# - Episode ends when the player dies (**it's inevitable becuse of limitted ammo**).
# <br><br>
# REWARDS:
# - +1 for killing a monster
# <br><br>
# - 3 available buttons: turn left, turn right, shoot (attack)
# - death penalty = 1

# %%
"""
Here we create our environment
"""
def create_environment():
    game = DoomGame()
    
    # Load the correct configuration
    game.load_config("defend_the_center.cfg")
    
    # Load the correct scenario (in our case defend_the_center scenario)
    game.set_doom_scenario_path("defend_the_center.wad")
    
    game.init()
    
    # Here our possible actions
    # [[1,0,0],[0,1,0],[0,0,1]]
    possible_actions  = np.identity(3,dtype=int).tolist()
    
    return game, possible_actions

# %%
game, possible_actions = create_environment()

# %% [markdown]
# ## Step 3: Define the preprocessing functions ⚙️
# ### preprocess_frame 🖼️
# Preprocessing is an important step, <b>because we want to reduce the complexity of our states to reduce the computation time needed for training.</b>
# <br><br>
# Our steps:
# - Grayscale each of our frames (because <b> color does not add important information </b>). But this is already done by the config file.
# - Crop the screen (in our case we remove the roof because it contains no information)
# - We normalize pixel values
# - Finally we resize the preprocessed frame

# %%
"""
    preprocess_frame:
    Take a frame.
    Resize it.
        __________________
        |                 |
        |                 |
        |                 |
        |                 |
        |_________________|
        
        to
        _____________
        |            |
        |            |
        |            |
        |____________|
    Normalize it.
    
    return preprocessed_frame
    
    """
def preprocess_frame(frame):
    # Greyscale frame already done in our vizdoom config
    # x = np.mean(frame,-1)
    
    # Crop the screen (remove the roof because it contains no information)
    # [Up: Down, Left: right]
    cropped_frame = frame[40:,:]
    
    # Normalize Pixel Values
    normalized_frame = cropped_frame/255.0
    
    # Resize
    preprocessed_frame = transform.resize(normalized_frame, [100,160])
    
    return preprocessed_frame

# %% [markdown]
# ### stack_frames
# 👏 This part was made possible thanks to help of <a href="https://github.com/Miffyli">Anssi</a><br>
#
# As explained in this really <a href="https://danieltakeshi.github.io/2016/11/25/frame-skipping-and-preprocessing-for-deep-q-networks-on-atari-2600-games/">  good article </a> we stack frames.
#
# Stacking frames is really important because it helps us to **give have a sense of motion to our Neural Network.**
#
# - First we preprocess frame
# - Then we append the frame to the deque that automatically **removes the oldest frame**
# - Finally we **build the stacked state**
#
# This is how work stack:
# - For the first frame, we feed 4 frames
# - At each timestep, **we add the new frame to deque and then we stack them to form a new stacked frame**
# - And so on
# <img src="https://raw.githubusercontent.com/simoninithomas/Deep_reinforcement_learning_Course/master/DQN/Space%20Invaders/assets/stack_frames.png" alt="stack">
# - If we're done, **we create a new stack with 4 new frames (because we are in a new episode)**.

# %%
stack_size = 4 # We stack 4 frames

# Initialize deque with zero-images one array for each image
stacked_frames  =  deque([np.zeros((100,160), dtype=np.int) for i in range(stack_size)], maxlen=4) 

def stack_frames(stacked_frames, state, is_new_episode):
    # Preprocess frame
    frame = preprocess_frame(state)
    
    if is_new_episode:
        # Clear our stacked_frames
        stacked_frames = deque([np.zeros((100,160), dtype=np.int) for i in range(stack_size)], maxlen=4)
        
        # Because we're in a new episode, copy the same frame 4x
        stacked_frames.append(frame)
        stacked_frames.append(frame)
        stacked_frames.append(frame)
        stacked_frames.append(frame)
        
        # Stack the frames
        stacked_state = np.stack(stacked_frames, axis=2)

    else:
        # Append frame to deque, automatically removes the oldest frame
        stacked_frames.append(frame)

        # Build the stacked state (first dimension specifies different frames)
        stacked_state = np.stack(stacked_frames, axis=2) 
    
    return stacked_state, stacked_frames

# %% [markdown]
# ### discount_and_normalize_rewards 💰
# This function is important, because we are in a Monte Carlo situation. <br>
#
# We need to **discount the rewards at the end of the episode**. This function takes, the reward discount it, and **then normalize them** (to avoid a big variability in rewards).

# %%
def discount_and_normalize_rewards(episode_rewards):
    discounted_episode_rewards = np.zeros_like(episode_rewards)
    cumulative = 0.0
    for i in reversed(range(len(episode_rewards))):
        cumulative = cumulative * gamma + episode_rewards[i]
        discounted_episode_rewards[i] = cumulative
    
    mean = np.mean(discounted_episode_rewards)
    std = np.std(discounted_episode_rewards)
    discounted_episode_rewards = (discounted_episode_rewards - mean) / (std)

    return discounted_episode_rewards

# %% [markdown]
# ## Step 4: Set up our hyperparameters ⚗️
# In this part we'll set up our different hyperparameters. But when you implement a Neural Network by yourself you will **not implement hyperparamaters at once but progressively**.
#
# - First, you begin by defining the neural networks hyperparameters when you implement the model.
# - Then, you'll add the training hyperparameters when you implement the training algorithm.

# %%
### ENVIRONMENT HYPERPARAMETERS
state_size = [100,160,4] # Our input is a stack of 4 frames hence 100x160x4 (Width, height, channels) 
action_size = game.get_available_buttons_size() # 3 possible actions: turn left, turn right, shoot
stack_size = 4 # Defines how many frames are stacked together

## TRAINING HYPERPARAMETERS
learning_rate = 0.0001 
num_epochs = 1000  # Total epochs for training 

batch_size = 1000 # Each 1 is a timestep (NOT AN EPISODE) # YOU CAN CHANGE TO 5000 if you have GPU
gamma = 0.99 # Discounting rate

### MODIFY THIS TO FALSE IF YOU JUST WANT TO SEE THE TRAINED AGENT
training = False

# %% [markdown]
# Quick note: Policy gradient methods like reinforce **are on-policy method which can not be updated from experience replay.**

# %% [markdown]
# ## Step 5: Create our Policy Gradient Neural Network model 🧠
#
# This is our Policy Gradient model:
# - We take a stack of 4 frames as input
# - It passes through 3 convnets
# - Then it is flatened
# - Finally it passes through 2 FC layers
# - It outputs a probability distribution over actions

# %% [markdown]
# <img src="assets/doomPG1.png" alt="Doom PG"/>

# %%
class PGNetwork:
    def __init__(self, state_size, action_size, learning_rate, name='PGNetwork'):
        self.state_size = state_size
        self.action_size = action_size
        self.learning_rate = learning_rate
        
        with tf.variable_scope(name):
            with tf.name_scope("inputs"):
                # We create the placeholders
                # *state_size means that we take each elements of state_size in tuple hence is like if we wrote
                # [None, 84, 84, 4]
                self.inputs_= tf.placeholder(tf.float32, [None, *state_size], name="inputs_")
                self.actions = tf.placeholder(tf.int32, [None, action_size], name="actions")
                self.discounted_episode_rewards_ = tf.placeholder(tf.float32, [None, ], name="discounted_episode_rewards_")
            
                
                # Add this placeholder for having this variable in tensorboard
                self.mean_reward_ = tf.placeholder(tf.float32, name="mean_reward")
                
            with tf.name_scope("conv1"):
                """
                First convnet:
                CNN
                BatchNormalization
                ELU
                """
                # Input is 84x84x4
                self.conv1 = tf.layers.conv2d(inputs = self.inputs_,
                                             filters = 32,
                                             kernel_size = [8,8],
                                             strides = [4,4],
                                             padding = "VALID",
                                              kernel_initializer=tf.contrib.layers.xavier_initializer_conv2d(),
                                             name = "conv1")

                self.conv1_batchnorm = tf.layers.batch_normalization(self.conv1,
                                                       training = True,
                                                       epsilon = 1e-5,
                                                         name = 'batch_norm1')

                self.conv1_out = tf.nn.elu(self.conv1_batchnorm, name="conv1_out")
                ## --> [20, 20, 32]
            
            with tf.name_scope("conv2"):
                """
                Second convnet:
                CNN
                BatchNormalization
                ELU
                """
                self.conv2 = tf.layers.conv2d(inputs = self.conv1_out,
                                     filters = 64,
                                     kernel_size = [4,4],
                                     strides = [2,2],
                                     padding = "VALID",
                                    kernel_initializer=tf.contrib.layers.xavier_initializer_conv2d(),
                                     name = "conv2")

                self.conv2_batchnorm = tf.layers.batch_normalization(self.conv2,
                                                       training = True,
                                                       epsilon = 1e-5,
                                                         name = 'batch_norm2')

                self.conv2_out = tf.nn.elu(self.conv2_batchnorm, name="conv2_out")
                ## --> [9, 9, 64]
            
            with tf.name_scope("conv3"):
                """
                Third convnet:
                CNN
                BatchNormalization
                ELU
                """
                self.conv3 = tf.layers.conv2d(inputs = self.conv2_out,
                                     filters = 128,
                                     kernel_size = [4,4],
                                     strides = [2,2],
                                     padding = "VALID",
                                    kernel_initializer=tf.contrib.layers.xavier_initializer_conv2d(),
                                     name = "conv3")

                self.conv3_batchnorm = tf.layers.batch_normalization(self.conv3,
                                                       training = True,
                                                       epsilon = 1e-5,
                                                         name = 'batch_norm3')

                self.conv3_out = tf.nn.elu(self.conv3_batchnorm, name="conv3_out")
                ## --> [3, 3, 128]
            
            with tf.name_scope("flatten"):
                self.flatten = tf.layers.flatten(self.conv3_out)
                ## --> [1152]
            
            with tf.name_scope("fc1"):
                self.fc = tf.layers.dense(inputs = self.flatten,
                                      units = 512,
                                      activation = tf.nn.elu,
                                           kernel_initializer=tf.contrib.layers.xavier_initializer(),
                                    name="fc1")
            
            with tf.name_scope("logits"):
                self.logits = tf.layers.dense(inputs = self.fc, 
                                               kernel_initializer=tf.contrib.layers.xavier_initializer(),
                                              units = 3, 
                                            activation=None)
            
            with tf.name_scope("softmax"):
                self.action_distribution = tf.nn.softmax(self.logits)
                

            with tf.name_scope("loss"):
                # tf.nn.softmax_cross_entropy_with_logits computes the cross entropy of the result after applying the softmax function
                # If you have single-class labels, where an object can only belong to one class, you might now consider using 
                # tf.nn.sparse_softmax_cross_entropy_with_logits so that you don't have to convert your labels to a dense one-hot array. 
                self.neg_log_prob = tf.nn.softmax_cross_entropy_with_logits_v2(logits = self.logits, labels = self.actions)
                self.loss = tf.reduce_mean(self.neg_log_prob * self.discounted_episode_rewards_) 
        
    
            with tf.name_scope("train"):
                self.train_opt = tf.train.RMSPropOptimizer(self.learning_rate).minimize(self.loss)

# %%
# Reset the graph
tf.reset_default_graph()

# Instantiate the PGNetwork
PGNetwork = PGNetwork(state_size, action_size, learning_rate)

# Initialize Session
sess = tf.Session()
init = tf.global_variables_initializer()
sess.run(init)

# %% [markdown]
# ## Step 6: Set up Tensorboard 📊
# For more information about tensorboard, please watch this <a href="https://www.youtube.com/embed/eBbEDRsCmv4">excellent 30min tutorial</a> <br><br>
# To launch tensorboard : `tensorboard --logdir=/tensorboard/policy_gradients/1`

# %%
# Setup TensorBoard Writer
writer = tf.summary.FileWriter("/tensorboard/policy_gradients/1")

## Losses
tf.summary.scalar("Loss", PGNetwork.loss)

## Reward mean
tf.summary.scalar("Reward_mean", PGNetwork.mean_reward_ )

write_op = tf.summary.merge_all()

# %% [markdown]
# ## Step 7: Train our Agent 🏃‍♂️

# %% [markdown]
# Here we'll create batches.<br>
# These batches contains episodes **(their number depends on how many rewards we collect**: for instance if we have episodes with only 10 rewards we can put batch_size/10 episodes
# <br>
# * Make a batch
#     * For each step:
#         * Choose action a
#         * Perform action a
#         * Store s, a, r
#         * **If** done:
#             * Calculate sum reward
#             * Calculate gamma Gt

# %%
def make_batch(batch_size, stacked_frames):
    # Initialize lists: states, actions, rewards_of_episode, rewards_of_batch, discounted_rewards
    states, actions, rewards_of_episode, rewards_of_batch, discounted_rewards = [], [], [], [], []
    
    # Reward of batch is also a trick to keep track of how many timestep we made.
    # We use to to verify at the end of each episode if > batch_size or not.
    
    # Keep track of how many episodes in our batch (useful when we'll need to calculate the average reward per episode)
    episode_num  = 1
    
    # Launch a new episode
    game.new_episode()
        
    # Get a new state
    state = game.get_state().screen_buffer
    state, stacked_frames = stack_frames(stacked_frames, state, True)

    while True:
        # Run State Through Policy & Calculate Action
        action_probability_distribution = sess.run(PGNetwork.action_distribution, 
                                                   feed_dict={PGNetwork.inputs_: state.reshape(1, *state_size)})
        
        # REMEMBER THAT WE ARE IN A STOCHASTIC POLICY SO WE DON'T ALWAYS TAKE THE ACTION WITH THE HIGHEST PROBABILITY
        # (For instance if the action with the best probability for state S is a1 with 70% chances, there is
        #30% chance that we take action a2)
        action = np.random.choice(range(action_probability_distribution.shape[1]), 
                                  p=action_probability_distribution.ravel())  # select action w.r.t the actions prob
        action = possible_actions[action]

        # Perform action
        reward = game.make_action(action)
        done = game.is_episode_finished()

        # Store results
        states.append(state)
        actions.append(action)
        rewards_of_episode.append(reward)
        
        if done:
            # The episode ends so no next state
            next_state = np.zeros((100, 160), dtype=np.int)
            next_state, stacked_frames = stack_frames(stacked_frames, next_state, False)
            
            # Append the rewards_of_batch to reward_of_episode
            rewards_of_batch.append(rewards_of_episode)
            
            # Calculate gamma Gt
            discounted_rewards.append(discount_and_normalize_rewards(rewards_of_episode))
           
            # If the number of rewards_of_batch > batch_size stop the minibatch creation
            # (Because we have sufficient number of episode mb)
            # Remember that we put this condition here, because we want entire episode (Monte Carlo)
            # so we can't check that condition for each step but only if an episode is finished
            if len(np.concatenate(rewards_of_batch)) > batch_size:
                break
                
            # Reset the transition stores
            rewards_of_episode = []
            
            # Add episode
            episode_num += 1
            
            # Start a new episode
            game.new_episode()

            # First we need a state
            state = game.get_state().screen_buffer

            # Stack the frames
            state, stacked_frames = stack_frames(stacked_frames, state, True)
         
        else:
            # If not done, the next_state become the current state
            next_state = game.get_state().screen_buffer
            next_state, stacked_frames = stack_frames(stacked_frames, next_state, False)
            state = next_state
                         
    return np.stack(np.array(states)), np.stack(np.array(actions)), np.concatenate(rewards_of_batch), np.concatenate(discounted_rewards), episode_num

# %% [markdown]
# * Create the Neural Network
# * Initialize the weights
# * Init the environment
# * maxReward = 0 # Keep track of maximum reward
# * **For** epochs in range(num_epochs):
#     * Get batches
#     * Optimize

# %%
# Keep track of all rewards total for each batch
allRewards = []

total_rewards = 0
maximumRewardRecorded = 0
mean_reward_total = []
epoch = 1
average_reward = []

# Saver
saver = tf.train.Saver()

if training:
    # Load the model
    #saver.restore(sess, "./models/model.ckpt")

    while epoch < num_epochs + 1:
        # Gather training data
        states_mb, actions_mb, rewards_of_batch, discounted_rewards_mb, nb_episodes_mb = make_batch(batch_size, stacked_frames)

        ### These part is used for analytics
        # Calculate the total reward ot the batch
        total_reward_of_that_batch = np.sum(rewards_of_batch)
        allRewards.append(total_reward_of_that_batch)

        # Calculate the mean reward of the batch
        # Total rewards of batch / nb episodes in that batch
        mean_reward_of_that_batch = np.divide(total_reward_of_that_batch, nb_episodes_mb)
        mean_reward_total.append(mean_reward_of_that_batch)

        # Calculate the average reward of all training
        # mean_reward_of_that_batch / epoch
        average_reward_of_all_training = np.divide(np.sum(mean_reward_total), epoch)

        # Calculate maximum reward recorded 
        maximumRewardRecorded = np.amax(allRewards)

        print("==========================================")
        print("Epoch: ", epoch, "/", num_epochs)
        print("-----------")
        print("Number of training episodes: {}".format(nb_episodes_mb))
        print("Total reward: {}".format(total_reward_of_that_batch, nb_episodes_mb))
        print("Mean Reward of that batch {}".format(mean_reward_of_that_batch))
        print("Average Reward of all training: {}".format(average_reward_of_all_training))
        print("Max reward for a batch so far: {}".format(maximumRewardRecorded))

        # Feedforward, gradient and backpropagation
        loss_, _ = sess.run([PGNetwork.loss, PGNetwork.train_opt], feed_dict={PGNetwork.inputs_: states_mb.reshape((len(states_mb), 100,160,4)),
                                                            PGNetwork.actions: actions_mb,
                                                                     PGNetwork.discounted_episode_rewards_: discounted_rewards_mb 
                                                                    })

        print("Training Loss: {}".format(loss_))

        # Write TF Summaries
        summary = sess.run(write_op, feed_dict={PGNetwork.inputs_: states_mb.reshape((len(states_mb), 100,160,4)),
                                                            PGNetwork.actions: actions_mb,
                                                                     PGNetwork.discounted_episode_rewards_: discounted_rewards_mb,
                                                                    PGNetwork.mean_reward_: mean_reward_of_that_batch
                                                                    })

        #summary = sess.run(write_op, feed_dict={x: s_.reshape(len(s_),84,84,1), y:a_, d_r: d_r_, r: r_, n: n_})
        writer.add_summary(summary, epoch)
        writer.flush()

        # Save Model
        if epoch % 10 == 0:
            saver.save(sess, "./models/model.ckpt")
            print("Model saved")
        epoch += 1
# Out:
# ==========================================
# Epoch:  1 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 7.0
# Mean Reward of that batch 2.3333333333333335
# Average Reward of all training: 2.3333333333333335
# Max reward for a batch so far: 7.0
# Training Loss: -0.013865186832845211
# ==========================================
# Epoch:  2 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 4.0
# Mean Reward of that batch 1.3333333333333333
# Average Reward of all training: 1.8333333333333335
# Max reward for a batch so far: 7.0
# Training Loss: 0.00959521159529686
# ==========================================
# Epoch:  3 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 5.0
# Mean Reward of that batch 1.6666666666666667
# Average Reward of all training: 1.777777777777778
# Max reward for a batch so far: 7.0
# Training Loss: 0.014865598641335964
# ==========================================
# Epoch:  4 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 4.0
# Mean Reward of that batch 1.3333333333333333
# Average Reward of all training: 1.6666666666666667
# Max reward for a batch so far: 7.0
# Training Loss: -0.006807255558669567
# ==========================================
# Epoch:  5 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 4.0
# Mean Reward of that batch 1.3333333333333333
# Average Reward of all training: 1.6
# Max reward for a batch so far: 7.0
# Training Loss: -0.028707260265946388
# ==========================================
# Epoch:  6 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 6.0
# Mean Reward of that batch 2.0
# Average Reward of all training: 1.6666666666666667
# Max reward for a batch so far: 7.0
# Training Loss: -0.0017251522513106465
# ==========================================
# Epoch:  7 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 7.0
# Mean Reward of that batch 2.3333333333333335
# Average Reward of all training: 1.761904761904762
# Max reward for a batch so far: 7.0
# Training Loss: 0.002758269663900137
# ==========================================
# Epoch:  8 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 6.0
# Mean Reward of that batch 2.0
# Average Reward of all training: 1.7916666666666667
# Max reward for a batch so far: 7.0
# Training Loss: 0.004145115148276091
# ==========================================
# Epoch:  9 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 2.0
# Mean Reward of that batch 0.6666666666666666
# Average Reward of all training: 1.6666666666666667
# Max reward for a batch so far: 7.0
# Training Loss: -0.0013189081801101565
# ==========================================
# Epoch:  10 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 8.0
# Mean Reward of that batch 2.6666666666666665
# Average Reward of all training: 1.7666666666666668
# Max reward for a batch so far: 8.0
# Training Loss: -9.403654985362664e-05
# Model saved
# ==========================================
# Epoch:  11 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 4.0
# Mean Reward of that batch 1.3333333333333333
# Average Reward of all training: 1.7272727272727273
# Max reward for a batch so far: 8.0
# Training Loss: 0.006883611902594566
# ==========================================
# Epoch:  12 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 5.0
# Mean Reward of that batch 1.6666666666666667
# Average Reward of all training: 1.7222222222222223
# Max reward for a batch so far: 8.0
# Training Loss: 0.00013329093053471297
# ==========================================
# Epoch:  13 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 6.0
# Mean Reward of that batch 2.0
# Average Reward of all training: 1.7435897435897436
# Max reward for a batch so far: 8.0
# Training Loss: -0.03658973425626755
# ==========================================
# Epoch:  14 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 3.0
# Mean Reward of that batch 1.0
# Average Reward of all training: 1.6904761904761905
# Max reward for a batch so far: 8.0
# Training Loss: 0.02367785945534706
# ==========================================
# Epoch:  15 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 7.0
# Mean Reward of that batch 2.3333333333333335
# Average Reward of all training: 1.7333333333333334
# Max reward for a batch so far: 8.0
# Training Loss: 0.02409999817609787
# ==========================================
# Epoch:  16 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 2.0
# Mean Reward of that batch 0.6666666666666666
# Average Reward of all training: 1.6666666666666667
# Max reward for a batch so far: 8.0
# Training Loss: -0.010288955643773079
# ==========================================
# Epoch:  17 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 7.0
# Mean Reward of that batch 2.3333333333333335
# Average Reward of all training: 1.7058823529411764
# Max reward for a batch so far: 8.0
# Training Loss: 0.00796806626021862
# ==========================================
# Epoch:  18 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 6.0
# Mean Reward of that batch 2.0
# Average Reward of all training: 1.7222222222222223
# Max reward for a batch so far: 8.0
# Training Loss: -0.01288426574319601
# ==========================================
# Epoch:  19 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 3.0
# Mean Reward of that batch 1.0
# Average Reward of all training: 1.6842105263157894
# Max reward for a batch so far: 8.0
# Training Loss: 0.02518601156771183
# ==========================================
# Epoch:  20 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 6.0
# Mean Reward of that batch 2.0
# Average Reward of all training: 1.7
# Max reward for a batch so far: 8.0
# Training Loss: -0.00694693997502327
# Model saved
# ==========================================
# Epoch:  21 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 4.0
# Mean Reward of that batch 1.3333333333333333
# Average Reward of all training: 1.6825396825396826
# Max reward for a batch so far: 8.0
# Training Loss: -0.04584670439362526
# ==========================================
# Epoch:  22 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 6.0
# Mean Reward of that batch 2.0
# Average Reward of all training: 1.696969696969697
# Max reward for a batch so far: 8.0
# Training Loss: -0.011263513937592506
# ==========================================
# Epoch:  23 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 8.0
# Mean Reward of that batch 2.6666666666666665
# Average Reward of all training: 1.7391304347826086
# Max reward for a batch so far: 8.0
# Training Loss: -0.04478195309638977
# ==========================================
# Epoch:  24 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 10.0
# Mean Reward of that batch 3.3333333333333335
# Average Reward of all training: 1.8055555555555556
# Max reward for a batch so far: 10.0
# Training Loss: -0.04996253177523613
# ==========================================
# Epoch:  25 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 9.0
# Mean Reward of that batch 3.0
# Average Reward of all training: 1.8533333333333335
# Max reward for a batch so far: 10.0
# Training Loss: 0.0029078619554638863
# ==========================================
# Epoch:  26 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 4.0
# Mean Reward of that batch 1.3333333333333333
# Average Reward of all training: 1.8333333333333335
# Max reward for a batch so far: 10.0
# Training Loss: 0.03545070439577103
# ==========================================
# Epoch:  27 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 10.0
# Mean Reward of that batch 3.3333333333333335
# Average Reward of all training: 1.888888888888889
# Max reward for a batch so far: 10.0
# Training Loss: 0.02897750400006771
# ==========================================
# Epoch:  28 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 9.0
# Mean Reward of that batch 3.0
# Average Reward of all training: 1.9285714285714288
# Max reward for a batch so far: 10.0
# Training Loss: -0.021074291318655014
# ==========================================
# Epoch:  29 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 8.0
# Mean Reward of that batch 2.6666666666666665
# Average Reward of all training: 1.9540229885057472
# Max reward for a batch so far: 10.0
# Training Loss: -0.026951875537633896
# ==========================================
# Epoch:  30 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 5.0
# Mean Reward of that batch 1.6666666666666667
# Average Reward of all training: 1.9444444444444444
# Max reward for a batch so far: 10.0
# Training Loss: -0.03115461766719818
# Model saved
# ==========================================
# Epoch:  31 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 8.0
# Mean Reward of that batch 2.6666666666666665
# Average Reward of all training: 1.967741935483871
# Max reward for a batch so far: 10.0
# Training Loss: -0.03791935369372368
# ==========================================
# Epoch:  32 / 1000
# -----------
# Number of training episodes: 2
# Total reward: 8.0
# Mean Reward of that batch 4.0
# Average Reward of all training: 2.03125
# Max reward for a batch so far: 10.0
# Training Loss: 0.05236440524458885
# ==========================================
# Epoch:  33 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 7.0
# Mean Reward of that batch 2.3333333333333335
# Average Reward of all training: 2.04040404040404
# Max reward for a batch so far: 10.0
# Training Loss: 0.0023908340372145176
# ==========================================
# Epoch:  34 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 6.0
# Mean Reward of that batch 2.0
# Average Reward of all training: 2.0392156862745097
# Max reward for a batch so far: 10.0
# Training Loss: 0.008738122880458832
# ==========================================
# Epoch:  35 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 11.0
# Mean Reward of that batch 3.6666666666666665
# Average Reward of all training: 2.085714285714286
# Max reward for a batch so far: 11.0
# Training Loss: -0.041010256856679916
# ==========================================
# Epoch:  36 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 8.0
# Mean Reward of that batch 2.6666666666666665
# Average Reward of all training: 2.101851851851852
# Max reward for a batch so far: 11.0
# Training Loss: 0.007362403906881809
# ==========================================
# Epoch:  37 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 8.0
# Mean Reward of that batch 2.6666666666666665
# Average Reward of all training: 2.1171171171171173
# Max reward for a batch so far: 11.0
# Training Loss: -0.016297398135066032
# ==========================================
# Epoch:  38 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 5.0
# Mean Reward of that batch 1.6666666666666667
# Average Reward of all training: 2.105263157894737
# Max reward for a batch so far: 11.0
# Training Loss: -0.014277423731982708
# ==========================================
# Epoch:  39 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 7.0
# Mean Reward of that batch 2.3333333333333335
# Average Reward of all training: 2.111111111111111
# Max reward for a batch so far: 11.0
# Training Loss: -0.029549162834882736
# ==========================================
# Epoch:  40 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 10.0
# Mean Reward of that batch 3.3333333333333335
# Average Reward of all training: 2.1416666666666666
# Max reward for a batch so far: 11.0
# Training Loss: -0.029198037460446358
# Model saved
# ==========================================
# Epoch:  41 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 7.0
# Mean Reward of that batch 2.3333333333333335
# Average Reward of all training: 2.146341463414634
# Max reward for a batch so far: 11.0
# Training Loss: -0.024994611740112305
# ==========================================
# Epoch:  42 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 10.0
# Mean Reward of that batch 3.3333333333333335
# Average Reward of all training: 2.174603174603174
# Max reward for a batch so far: 11.0
# Training Loss: -0.011647643521428108
# ==========================================
# Epoch:  43 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 9.0
# Mean Reward of that batch 3.0
# Average Reward of all training: 2.1937984496124026
# Max reward for a batch so far: 11.0
# Training Loss: -0.0005224175984039903
# ==========================================
# Epoch:  44 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 9.0
# Mean Reward of that batch 3.0
# Average Reward of all training: 2.2121212121212115
# Max reward for a batch so far: 11.0
# Training Loss: 0.014835077337920666
# ==========================================
# Epoch:  45 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 6.0
# Mean Reward of that batch 2.0
# Average Reward of all training: 2.207407407407407
# Max reward for a batch so far: 11.0
# Training Loss: 0.017055697739124298
# ==========================================
# Epoch:  46 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 8.0
# Mean Reward of that batch 2.6666666666666665
# Average Reward of all training: 2.2173913043478257
# Max reward for a batch so far: 11.0
# Training Loss: -0.004047002177685499
# ==========================================
# Epoch:  47 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 9.0
# Mean Reward of that batch 3.0
# Average Reward of all training: 2.234042553191489
# Max reward for a batch so far: 11.0
# Training Loss: -0.03151952847838402
# ==========================================
# Epoch:  48 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 8.0
# Mean Reward of that batch 2.6666666666666665
# Average Reward of all training: 2.2430555555555554
# Max reward for a batch so far: 11.0
# Training Loss: -0.011581013910472393
# ==========================================
# Epoch:  49 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 10.0
# Mean Reward of that batch 3.3333333333333335
# Average Reward of all training: 2.265306122448979
# Max reward for a batch so far: 11.0
# Training Loss: 0.014105113223195076
# ==========================================
# Epoch:  50 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 8.0
# Mean Reward of that batch 2.6666666666666665
# Average Reward of all training: 2.273333333333333
# Max reward for a batch so far: 11.0
# Training Loss: 0.006287877447903156
# Model saved
# ==========================================
# Epoch:  51 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 8.0
# Mean Reward of that batch 2.6666666666666665
# Average Reward of all training: 2.281045751633987
# Max reward for a batch so far: 11.0
# Training Loss: 0.011337721720337868
# ==========================================
# Epoch:  52 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 9.0
# Mean Reward of that batch 3.0
# Average Reward of all training: 2.2948717948717947
# Max reward for a batch so far: 11.0
# Training Loss: -0.0015647724503651261
# ==========================================
# Epoch:  53 / 1000
# -----------
# Number of training episodes: 2
# Total reward: 10.0
# Mean Reward of that batch 5.0
# Average Reward of all training: 2.3459119496855343
# Max reward for a batch so far: 11.0
# Training Loss: 0.004807328339666128
# ==========================================
# Epoch:  54 / 1000
# -----------
# Number of training episodes: 2
# Total reward: 8.0
# Mean Reward of that batch 4.0
# Average Reward of all training: 2.3765432098765427
# Max reward for a batch so far: 11.0
# Training Loss: -0.06360957771539688
# ==========================================
# Epoch:  55 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 8.0
# Mean Reward of that batch 2.6666666666666665
# Average Reward of all training: 2.3818181818181814
# Max reward for a batch so far: 11.0
# Training Loss: 0.002144009340554476
# ==========================================
# Epoch:  56 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 6.0
# Mean Reward of that batch 2.0
# Average Reward of all training: 2.375
# Max reward for a batch so far: 11.0
# Training Loss: 0.028096342459321022
# ==========================================
# Epoch:  57 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 8.0
# Mean Reward of that batch 2.6666666666666665
# Average Reward of all training: 2.380116959064327
# Max reward for a batch so far: 11.0
# Training Loss: -0.01865851692855358
# ==========================================
# Epoch:  58 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 6.0
# Mean Reward of that batch 2.0
# Average Reward of all training: 2.3735632183908044
# Max reward for a batch so far: 11.0
# Training Loss: -0.011348516680300236
# ==========================================
# Epoch:  59 / 1000
# -----------
# Number of training episodes: 2
# Total reward: 7.0
# Mean Reward of that batch 3.5
# Average Reward of all training: 2.3926553672316384
# Max reward for a batch so far: 11.0
# Training Loss: -0.037985093891620636
# ==========================================
# Epoch:  60 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 9.0
# Mean Reward of that batch 3.0
# Average Reward of all training: 2.4027777777777777
# Max reward for a batch so far: 11.0
# Training Loss: -0.005700449924916029
# Model saved
# ==========================================
# Epoch:  61 / 1000
# -----------
# Number of training episodes: 2
# Total reward: 7.0
# Mean Reward of that batch 3.5
# Average Reward of all training: 2.420765027322404
# Max reward for a batch so far: 11.0
# Training Loss: -0.03312378376722336
# ==========================================
# Epoch:  62 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 8.0
# Mean Reward of that batch 2.6666666666666665
# Average Reward of all training: 2.4247311827956985
# Max reward for a batch so far: 11.0
# Training Loss: -0.03841271623969078
# ==========================================
# Epoch:  63 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 3.0
# Mean Reward of that batch 1.0
# Average Reward of all training: 2.402116402116402
# Max reward for a batch so far: 11.0
# Training Loss: -0.0006252923631109297
# ==========================================
# Epoch:  64 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 8.0
# Mean Reward of that batch 2.6666666666666665
# Average Reward of all training: 2.40625
# Max reward for a batch so far: 11.0
# Training Loss: -0.04918909817934036
# ==========================================
# Epoch:  65 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 7.0
# Mean Reward of that batch 2.3333333333333335
# Average Reward of all training: 2.4051282051282055
# Max reward for a batch so far: 11.0
# Training Loss: 0.001828608801588416
# ==========================================
# Epoch:  66 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 8.0
# Mean Reward of that batch 2.6666666666666665
# Average Reward of all training: 2.409090909090909
# Max reward for a batch so far: 11.0
# Training Loss: 0.004482969641685486
# ==========================================
# Epoch:  67 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 5.0
# Mean Reward of that batch 1.6666666666666667
# Average Reward of all training: 2.398009950248756
# Max reward for a batch so far: 11.0
# Training Loss: -0.017204634845256805
# ==========================================
# Epoch:  68 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 5.0
# Mean Reward of that batch 1.6666666666666667
# Average Reward of all training: 2.387254901960784
# Max reward for a batch so far: 11.0
# Training Loss: -0.009284823201596737
# ==========================================
# Epoch:  69 / 1000
# -----------
# Number of training episodes: 2
# Total reward: 8.0
# Mean Reward of that batch 4.0
# Average Reward of all training: 2.410628019323671
# Max reward for a batch so far: 11.0
# Training Loss: -0.078486867249012
# ==========================================
# Epoch:  70 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 11.0
# Mean Reward of that batch 3.6666666666666665
# Average Reward of all training: 2.4285714285714284
# Max reward for a batch so far: 11.0
# Training Loss: -0.039177555590867996
# Model saved
# ==========================================
# Epoch:  71 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 6.0
# Mean Reward of that batch 2.0
# Average Reward of all training: 2.422535211267605
# Max reward for a batch so far: 11.0
# Training Loss: -0.05283205211162567
# ==========================================
# Epoch:  72 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 9.0
# Mean Reward of that batch 3.0
# Average Reward of all training: 2.4305555555555554
# Max reward for a batch so far: 11.0
# Training Loss: 0.004480014089494944
# ==========================================
# Epoch:  73 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 8.0
# Mean Reward of that batch 2.6666666666666665
# Average Reward of all training: 2.4337899543378994
# Max reward for a batch so far: 11.0
# Training Loss: -0.03119450993835926
# ==========================================
# Epoch:  74 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 7.0
# Mean Reward of that batch 2.3333333333333335
# Average Reward of all training: 2.4324324324324325
# Max reward for a batch so far: 11.0
# Training Loss: 0.021401777863502502
# ==========================================
# Epoch:  75 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 2.0
# Mean Reward of that batch 0.6666666666666666
# Average Reward of all training: 2.408888888888889
# Max reward for a batch so far: 11.0
# Training Loss: 0.06659503281116486
# ==========================================
# Epoch:  76 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 9.0
# Mean Reward of that batch 3.0
# Average Reward of all training: 2.4166666666666665
# Max reward for a batch so far: 11.0
# Training Loss: -0.016507480293512344
# ==========================================
# Epoch:  77 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 6.0
# Mean Reward of that batch 2.0
# Average Reward of all training: 2.411255411255411
# Max reward for a batch so far: 11.0
# Training Loss: 0.009119314141571522
# ==========================================
# Epoch:  78 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 10.0
# Mean Reward of that batch 3.3333333333333335
# Average Reward of all training: 2.423076923076923
# Max reward for a batch so far: 11.0
# Training Loss: -0.014694495126605034
# ==========================================
# Epoch:  79 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 9.0
# Mean Reward of that batch 3.0
# Average Reward of all training: 2.430379746835443
# Max reward for a batch so far: 11.0
# Training Loss: 0.04039096087217331
# ==========================================
# Epoch:  80 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 7.0
# Mean Reward of that batch 2.3333333333333335
# Average Reward of all training: 2.4291666666666667
# Max reward for a batch so far: 11.0
# Training Loss: -0.025414828211069107
# Model saved
# ==========================================
# Epoch:  81 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 10.0
# Mean Reward of that batch 3.3333333333333335
# Average Reward of all training: 2.440329218106996
# Max reward for a batch so far: 11.0
# Training Loss: -0.01862708479166031
# ==========================================
# Epoch:  82 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 10.0
# Mean Reward of that batch 3.3333333333333335
# Average Reward of all training: 2.4512195121951224
# Max reward for a batch so far: 11.0
# Training Loss: 0.018017873167991638
# ==========================================
# Epoch:  83 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 7.0
# Mean Reward of that batch 2.3333333333333335
# Average Reward of all training: 2.449799196787149
# Max reward for a batch so far: 11.0
# Training Loss: 0.008148613385856152
# ==========================================
# Epoch:  84 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 8.0
# Mean Reward of that batch 2.6666666666666665
# Average Reward of all training: 2.4523809523809526
# Max reward for a batch so far: 11.0
# Training Loss: 0.010709865018725395
# ==========================================
# Epoch:  85 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 11.0
# Mean Reward of that batch 3.6666666666666665
# Average Reward of all training: 2.466666666666667
# Max reward for a batch so far: 11.0
# Training Loss: 0.04373529553413391
# ==========================================
# Epoch:  86 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 7.0
# Mean Reward of that batch 2.3333333333333335
# Average Reward of all training: 2.465116279069768
# Max reward for a batch so far: 11.0
# Training Loss: 0.02377723716199398
# ==========================================
# Epoch:  87 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 7.0
# Mean Reward of that batch 2.3333333333333335
# Average Reward of all training: 2.46360153256705
# Max reward for a batch so far: 11.0
# Training Loss: -0.035754378885030746
# ==========================================
# Epoch:  88 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 9.0
# Mean Reward of that batch 3.0
# Average Reward of all training: 2.4696969696969697
# Max reward for a batch so far: 11.0
# Training Loss: -0.05035744979977608
# ==========================================
# Epoch:  89 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 8.0
# Mean Reward of that batch 2.6666666666666665
# Average Reward of all training: 2.4719101123595504
# Max reward for a batch so far: 11.0
# Training Loss: 0.04073116555809975
# ==========================================
# Epoch:  90 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 13.0
# Mean Reward of that batch 4.333333333333333
# Average Reward of all training: 2.492592592592593
# Max reward for a batch so far: 13.0
# Training Loss: -0.03041957877576351
# Model saved
# ==========================================
# Epoch:  91 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 11.0
# Mean Reward of that batch 3.6666666666666665
# Average Reward of all training: 2.5054945054945055
# Max reward for a batch so far: 13.0
# Training Loss: 0.013735701330006123
# ==========================================
# Epoch:  92 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 10.0
# Mean Reward of that batch 3.3333333333333335
# Average Reward of all training: 2.5144927536231885
# Max reward for a batch so far: 13.0
# Training Loss: 0.002050180220976472
# ==========================================
# Epoch:  93 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 7.0
# Mean Reward of that batch 2.3333333333333335
# Average Reward of all training: 2.512544802867384
# Max reward for a batch so far: 13.0
# Training Loss: -0.011413732543587685
# ==========================================
# Epoch:  94 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 8.0
# Mean Reward of that batch 2.6666666666666665
# Average Reward of all training: 2.514184397163121
# Max reward for a batch so far: 13.0
# Training Loss: 0.006887589115649462
# ==========================================
# Epoch:  95 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 7.0
# Mean Reward of that batch 2.3333333333333335
# Average Reward of all training: 2.5122807017543862
# Max reward for a batch so far: 13.0
# Training Loss: -0.05172683671116829
# ==========================================
# Epoch:  96 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 6.0
# Mean Reward of that batch 2.0
# Average Reward of all training: 2.5069444444444446
# Max reward for a batch so far: 13.0
# Training Loss: -0.01659564860165119
# ==========================================
# Epoch:  97 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 8.0
# Mean Reward of that batch 2.6666666666666665
# Average Reward of all training: 2.508591065292096
# Max reward for a batch so far: 13.0
# Training Loss: -0.012522476725280285
# ==========================================
# Epoch:  98 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 8.0
# Mean Reward of that batch 2.6666666666666665
# Average Reward of all training: 2.510204081632653
# Max reward for a batch so far: 13.0
# Training Loss: -0.01633165404200554
# ==========================================
# Epoch:  99 / 1000
# -----------
# Number of training episodes: 2
# Total reward: 11.0
# Mean Reward of that batch 5.5
# Average Reward of all training: 2.54040404040404
# Max reward for a batch so far: 13.0
# Training Loss: 0.00720728375017643
# ==========================================
# Epoch:  100 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 10.0
# Mean Reward of that batch 3.3333333333333335
# Average Reward of all training: 2.5483333333333333
# Max reward for a batch so far: 13.0
# Training Loss: -0.025992214679718018
# Model saved
# ==========================================
# Epoch:  101 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 5.0
# Mean Reward of that batch 1.6666666666666667
# Average Reward of all training: 2.5396039603960396
# Max reward for a batch so far: 13.0
# Training Loss: -0.01922825165092945
# ==========================================
# Epoch:  102 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 1.0
# Mean Reward of that batch 0.3333333333333333
# Average Reward of all training: 2.5179738562091503
# Max reward for a batch so far: 13.0
# Training Loss: 0.02124018594622612
# ==========================================
# Epoch:  103 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 9.0
# Mean Reward of that batch 3.0
# Average Reward of all training: 2.5226537216828477
# Max reward for a batch so far: 13.0
# Training Loss: -0.014413237571716309
# ==========================================
# Epoch:  104 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 10.0
# Mean Reward of that batch 3.3333333333333335
# Average Reward of all training: 2.5304487179487176
# Max reward for a batch so far: 13.0
# Training Loss: 0.0002957126416731626
# ==========================================
# Epoch:  105 / 1000
# -----------
# Number of training episodes: 4
# Total reward: 0.0
# Mean Reward of that batch 0.0
# Average Reward of all training: 2.506349206349206
# Max reward for a batch so far: 13.0
# Training Loss: 0.011509822681546211
# ==========================================
# Epoch:  106 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 10.0
# Mean Reward of that batch 3.3333333333333335
# Average Reward of all training: 2.514150943396226
# Max reward for a batch so far: 13.0
# Training Loss: 0.002280993154272437
# ==========================================
# Epoch:  107 / 1000
# -----------
# Number of training episodes: 4
# Total reward: 0.0
# Mean Reward of that batch 0.0
# Average Reward of all training: 2.490654205607476
# Max reward for a batch so far: 13.0
# Training Loss: 0.044227536767721176
# ==========================================
# Epoch:  108 / 1000
# -----------
# Number of training episodes: 4
# Total reward: 1.0
# Mean Reward of that batch 0.25
# Average Reward of all training: 2.469907407407407
# Max reward for a batch so far: 13.0
# Training Loss: -0.01253164280205965
# ==========================================
# Epoch:  109 / 1000
# -----------
# Number of training episodes: 4
# Total reward: 0.0
# Mean Reward of that batch 0.0
# Average Reward of all training: 2.4472477064220177
# Max reward for a batch so far: 13.0
# Training Loss: -0.002042862819507718
# ==========================================
# Epoch:  110 / 1000
# -----------
# Number of training episodes: 4
# Total reward: 2.0
# Mean Reward of that batch 0.5
# Average Reward of all training: 2.4295454545454542
# Max reward for a batch so far: 13.0
# Training Loss: -0.006498878821730614
# Model saved
# ==========================================
# Epoch:  111 / 1000
# -----------
# Number of training episodes: 4
# Total reward: 0.0
# Mean Reward of that batch 0.0
# Average Reward of all training: 2.407657657657657
# Max reward for a batch so far: 13.0
# Training Loss: -0.02264668047428131
# ==========================================
# Epoch:  112 / 1000
# -----------
# Number of training episodes: 4
# Total reward: 2.0
# Mean Reward of that batch 0.5
# Average Reward of all training: 2.390625
# Max reward for a batch so far: 13.0
# Training Loss: -0.026582827791571617
# ==========================================
# Epoch:  113 / 1000
# -----------
# Number of training episodes: 4
# Total reward: 1.0
# Mean Reward of that batch 0.25
# Average Reward of all training: 2.3716814159292037
# Max reward for a batch so far: 13.0
# Training Loss: -0.012644077651202679
# ==========================================
# Epoch:  114 / 1000
# -----------
# Number of training episodes: 4
# Total reward: 3.0
# Mean Reward of that batch 0.75
# Average Reward of all training: 2.357456140350877
# Max reward for a batch so far: 13.0
# Training Loss: -0.026349905878305435
# ==========================================
# Epoch:  115 / 1000
# -----------
# Number of training episodes: 4
# Total reward: 1.0
# Mean Reward of that batch 0.25
# Average Reward of all training: 2.3391304347826085
# Max reward for a batch so far: 13.0
# Training Loss: 0.0011913379421457648
# ==========================================
# Epoch:  116 / 1000
# -----------
# Number of training episodes: 4
# Total reward: 4.0
# Mean Reward of that batch 1.0
# Average Reward of all training: 2.3275862068965516
# Max reward for a batch so far: 13.0
# Training Loss: -0.02623582072556019
# ==========================================
# Epoch:  117 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 9.0
# Mean Reward of that batch 3.0
# Average Reward of all training: 2.3333333333333335
# Max reward for a batch so far: 13.0
# Training Loss: -0.02706248126924038
# ==========================================
# Epoch:  118 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 11.0
# Mean Reward of that batch 3.6666666666666665
# Average Reward of all training: 2.344632768361582
# Max reward for a batch so far: 13.0
# Training Loss: -0.057436831295490265
# ==========================================
# Epoch:  119 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 12.0
# Mean Reward of that batch 4.0
# Average Reward of all training: 2.358543417366947
# Max reward for a batch so far: 13.0
# Training Loss: -0.10546118021011353
# ==========================================
# Epoch:  120 / 1000
# -----------
# Number of training episodes: 4
# Total reward: 0.0
# Mean Reward of that batch 0.0
# Average Reward of all training: 2.3388888888888886
# Max reward for a batch so far: 13.0
# Training Loss: -0.08961080759763718
# Model saved
# ==========================================
# Epoch:  121 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 15.0
# Mean Reward of that batch 5.0
# Average Reward of all training: 2.3608815426997243
# Max reward for a batch so far: 15.0
# Training Loss: 0.0795603021979332
# ==========================================
# Epoch:  122 / 1000
# -----------
# Number of training episodes: 4
# Total reward: 7.0
# Mean Reward of that batch 1.75
# Average Reward of all training: 2.3558743169398904
# Max reward for a batch so far: 15.0
# Training Loss: -0.05411568656563759
# ==========================================
# Epoch:  123 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 9.0
# Mean Reward of that batch 3.0
# Average Reward of all training: 2.3611111111111107
# Max reward for a batch so far: 15.0
# Training Loss: 0.08060659468173981
# ==========================================
# Epoch:  124 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 2.0
# Mean Reward of that batch 0.6666666666666666
# Average Reward of all training: 2.3474462365591395
# Max reward for a batch so far: 15.0
# Training Loss: -0.07357233762741089
# ==========================================
# Epoch:  125 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 6.0
# Mean Reward of that batch 2.0
# Average Reward of all training: 2.3446666666666665
# Max reward for a batch so far: 15.0
# Training Loss: 0.0665055438876152
# ==========================================
# Epoch:  126 / 1000
# -----------
# Number of training episodes: 4
# Total reward: 0.0
# Mean Reward of that batch 0.0
# Average Reward of all training: 2.326058201058201
# Max reward for a batch so far: 15.0
# Training Loss: -0.02599966526031494
# ==========================================
# Epoch:  127 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 5.0
# Mean Reward of that batch 1.6666666666666667
# Average Reward of all training: 2.3208661417322833
# Max reward for a batch so far: 15.0
# Training Loss: 0.0008016353822313249
# ==========================================
# Epoch:  128 / 1000
# -----------
# Number of training episodes: 4
# Total reward: 0.0
# Mean Reward of that batch 0.0
# Average Reward of all training: 2.302734375
# Max reward for a batch so far: 15.0
# Training Loss: -0.047914426773786545
# ==========================================
# Epoch:  129 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 9.0
# Mean Reward of that batch 3.0
# Average Reward of all training: 2.308139534883721
# Max reward for a batch so far: 15.0
# Training Loss: 0.03262101113796234
# ==========================================
# Epoch:  130 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 7.0
# Mean Reward of that batch 2.3333333333333335
# Average Reward of all training: 2.3083333333333336
# Max reward for a batch so far: 15.0
# Training Loss: 0.02984907105565071
# Model saved
# ==========================================
# Epoch:  131 / 1000
# -----------
# Number of training episodes: 4
# Total reward: 4.0
# Mean Reward of that batch 1.0
# Average Reward of all training: 2.298346055979644
# Max reward for a batch so far: 15.0
# Training Loss: -0.06604704260826111
# ==========================================
# Epoch:  132 / 1000
# -----------
# Number of training episodes: 4
# Total reward: 4.0
# Mean Reward of that batch 1.0
# Average Reward of all training: 2.288510101010101
# Max reward for a batch so far: 15.0
# Training Loss: -0.06369294226169586
# ==========================================
# Epoch:  133 / 1000
# -----------
# Number of training episodes: 4
# Total reward: 6.0
# Mean Reward of that batch 1.5
# Average Reward of all training: 2.2825814536340854
# Max reward for a batch so far: 15.0
# Training Loss: -0.0001370279787806794
# ==========================================
# Epoch:  134 / 1000
# -----------
# Number of training episodes: 4
# Total reward: 1.0
# Mean Reward of that batch 0.25
# Average Reward of all training: 2.2674129353233834
# Max reward for a batch so far: 15.0
# Training Loss: -0.06792200356721878
# ==========================================
# Epoch:  135 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 10.0
# Mean Reward of that batch 3.3333333333333335
# Average Reward of all training: 2.275308641975309
# Max reward for a batch so far: 15.0
# Training Loss: 0.013899818994104862
# ==========================================
# Epoch:  136 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 6.0
# Mean Reward of that batch 2.0
# Average Reward of all training: 2.27328431372549
# Max reward for a batch so far: 15.0
# Training Loss: 0.027764398604631424
# ==========================================
# Epoch:  137 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 3.0
# Mean Reward of that batch 1.0
# Average Reward of all training: 2.2639902676399024
# Max reward for a batch so far: 15.0
# Training Loss: -0.003979032393544912
# ==========================================
# Epoch:  138 / 1000
# -----------
# Number of training episodes: 4
# Total reward: 3.0
# Mean Reward of that batch 0.75
# Average Reward of all training: 2.2530193236714973
# Max reward for a batch so far: 15.0
# Training Loss: -0.03662572428584099
# ==========================================
# Epoch:  139 / 1000
# -----------
# Number of training episodes: 4
# Total reward: 3.0
# Mean Reward of that batch 0.75
# Average Reward of all training: 2.2422062350119902
# Max reward for a batch so far: 15.0
# Training Loss: -0.061255697160959244
# ==========================================
# Epoch:  140 / 1000
# -----------
# Number of training episodes: 4
# Total reward: 5.0
# Mean Reward of that batch 1.25
# Average Reward of all training: 2.2351190476190474
# Max reward for a batch so far: 15.0
# Training Loss: -0.006506932899355888
# Model saved
# ==========================================
# Epoch:  141 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 5.0
# Mean Reward of that batch 1.6666666666666667
# Average Reward of all training: 2.2310874704491725
# Max reward for a batch so far: 15.0
# Training Loss: -0.011820721440017223
# ==========================================
# Epoch:  142 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 5.0
# Mean Reward of that batch 1.6666666666666667
# Average Reward of all training: 2.227112676056338
# Max reward for a batch so far: 15.0
# Training Loss: -0.005799064412713051
# ==========================================
# Epoch:  143 / 1000
# -----------
# Number of training episodes: 4
# Total reward: 6.0
# Mean Reward of that batch 1.5
# Average Reward of all training: 2.222027972027972
# Max reward for a batch so far: 15.0
# Training Loss: -0.049054358154535294
# ==========================================
# Epoch:  144 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 10.0
# Mean Reward of that batch 3.3333333333333335
# Average Reward of all training: 2.2297453703703702
# Max reward for a batch so far: 15.0
# Training Loss: 0.0070181358605623245
# ==========================================
# Epoch:  145 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 11.0
# Mean Reward of that batch 3.6666666666666665
# Average Reward of all training: 2.239655172413793
# Max reward for a batch so far: 15.0
# Training Loss: 0.023341812193393707
# ==========================================
# Epoch:  146 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 14.0
# Mean Reward of that batch 4.666666666666667
# Average Reward of all training: 2.256278538812785
# Max reward for a batch so far: 15.0
# Training Loss: 0.038932736963033676
# ==========================================
# Epoch:  147 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 9.0
# Mean Reward of that batch 3.0
# Average Reward of all training: 2.2613378684807253
# Max reward for a batch so far: 15.0
# Training Loss: 0.01905321702361107
# ==========================================
# Epoch:  148 / 1000
# -----------
# Number of training episodes: 4
# Total reward: 5.0
# Mean Reward of that batch 1.25
# Average Reward of all training: 2.2545045045045042
# Max reward for a batch so far: 15.0
# Training Loss: -0.03653639927506447
# ==========================================
# Epoch:  149 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 9.0
# Mean Reward of that batch 3.0
# Average Reward of all training: 2.2595078299776286
# Max reward for a batch so far: 15.0
# Training Loss: 0.05068114772439003
# ==========================================
# Epoch:  150 / 1000
# -----------
# Number of training episodes: 4
# Total reward: 3.0
# Mean Reward of that batch 0.75
# Average Reward of all training: 2.2494444444444444
# Max reward for a batch so far: 15.0
# Training Loss: -0.18852214515209198
# Model saved
# ==========================================
# Epoch:  151 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 10.0
# Mean Reward of that batch 3.3333333333333335
# Average Reward of all training: 2.256622516556291
# Max reward for a batch so far: 15.0
# Training Loss: -0.06198088079690933
# ==========================================
# Epoch:  152 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 8.0
# Mean Reward of that batch 2.6666666666666665
# Average Reward of all training: 2.2593201754385963
# Max reward for a batch so far: 15.0
# Training Loss: 0.018179720267653465
# ==========================================
# Epoch:  153 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 10.0
# Mean Reward of that batch 3.3333333333333335
# Average Reward of all training: 2.2663398692810457
# Max reward for a batch so far: 15.0
# Training Loss: -0.004519591573625803
# ==========================================
# Epoch:  154 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 6.0
# Mean Reward of that batch 2.0
# Average Reward of all training: 2.2646103896103895
# Max reward for a batch so far: 15.0
# Training Loss: -0.02128661423921585
# ==========================================
# Epoch:  155 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 5.0
# Mean Reward of that batch 1.6666666666666667
# Average Reward of all training: 2.2607526881720426
# Max reward for a batch so far: 15.0
# Training Loss: -0.0025869214441627264
# ==========================================
# Epoch:  156 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 11.0
# Mean Reward of that batch 3.6666666666666665
# Average Reward of all training: 2.269764957264957
# Max reward for a batch so far: 15.0
# Training Loss: 0.023080753162503242
# ==========================================
# Epoch:  157 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 14.0
# Mean Reward of that batch 4.666666666666667
# Average Reward of all training: 2.285031847133758
# Max reward for a batch so far: 15.0
# Training Loss: 0.03209206089377403
# ==========================================
# Epoch:  158 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 10.0
# Mean Reward of that batch 3.3333333333333335
# Average Reward of all training: 2.2916666666666665
# Max reward for a batch so far: 15.0
# Training Loss: -0.020097505301237106
# ==========================================
# Epoch:  159 / 1000
# -----------
# Number of training episodes: 2
# Total reward: 9.0
# Mean Reward of that batch 4.5
# Average Reward of all training: 2.3055555555555554
# Max reward for a batch so far: 15.0
# Training Loss: 0.005053423345088959
# ==========================================
# Epoch:  160 / 1000
# -----------
# Number of training episodes: 2
# Total reward: 9.0
# Mean Reward of that batch 4.5
# Average Reward of all training: 2.3192708333333334
# Max reward for a batch so far: 15.0
# Training Loss: 0.03465461730957031
# Model saved
# ==========================================
# Epoch:  161 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 12.0
# Mean Reward of that batch 4.0
# Average Reward of all training: 2.3297101449275366
# Max reward for a batch so far: 15.0
# Training Loss: 0.03056580014526844
# ==========================================
# Epoch:  162 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 13.0
# Mean Reward of that batch 4.333333333333333
# Average Reward of all training: 2.3420781893004117
# Max reward for a batch so far: 15.0
# Training Loss: 0.02352350577712059
# ==========================================
# Epoch:  163 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 12.0
# Mean Reward of that batch 4.0
# Average Reward of all training: 2.3522494887525562
# Max reward for a batch so far: 15.0
# Training Loss: 0.001978909596800804
# ==========================================
# Epoch:  164 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 6.0
# Mean Reward of that batch 2.0
# Average Reward of all training: 2.35010162601626
# Max reward for a batch so far: 15.0
# Training Loss: 0.001422384288161993
# ==========================================
# Epoch:  165 / 1000
# -----------
# Number of training episodes: 2
# Total reward: 10.0
# Mean Reward of that batch 5.0
# Average Reward of all training: 2.3661616161616164
# Max reward for a batch so far: 15.0
# Training Loss: -0.002413789974525571
# ==========================================
# Epoch:  166 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 16.0
# Mean Reward of that batch 5.333333333333333
# Average Reward of all training: 2.3840361445783134
# Max reward for a batch so far: 16.0
# Training Loss: -0.021699795499444008
# ==========================================
# Epoch:  167 / 1000
# -----------
# Number of training episodes: 2
# Total reward: 15.0
# Mean Reward of that batch 7.5
# Average Reward of all training: 2.4146706586826348
# Max reward for a batch so far: 16.0
# Training Loss: -0.05096929520368576
# ==========================================
# Epoch:  168 / 1000
# -----------
# Number of training episodes: 2
# Total reward: 10.0
# Mean Reward of that batch 5.0
# Average Reward of all training: 2.4300595238095237
# Max reward for a batch so far: 16.0
# Training Loss: -0.1511044204235077
# ==========================================
# Epoch:  169 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 5.0
# Mean Reward of that batch 1.6666666666666667
# Average Reward of all training: 2.4255424063116373
# Max reward for a batch so far: 16.0
# Training Loss: 0.04504809156060219
# ==========================================
# Epoch:  170 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 13.0
# Mean Reward of that batch 4.333333333333333
# Average Reward of all training: 2.4367647058823527
# Max reward for a batch so far: 16.0
# Training Loss: 0.09613463282585144
# Model saved
# ==========================================
# Epoch:  171 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 13.0
# Mean Reward of that batch 4.333333333333333
# Average Reward of all training: 2.4478557504873297
# Max reward for a batch so far: 16.0
# Training Loss: -0.11585640907287598
# ==========================================
# Epoch:  172 / 1000
# -----------
# Number of training episodes: 2
# Total reward: 10.0
# Mean Reward of that batch 5.0
# Average Reward of all training: 2.4626937984496124
# Max reward for a batch so far: 16.0
# Training Loss: -0.02525159902870655
# ==========================================
# Epoch:  173 / 1000
# -----------
# Number of training episodes: 4
# Total reward: 6.0
# Mean Reward of that batch 1.5
# Average Reward of all training: 2.4571290944123314
# Max reward for a batch so far: 16.0
# Training Loss: -0.04511270299553871
# ==========================================
# Epoch:  174 / 1000
# -----------
# Number of training episodes: 4
# Total reward: 0.0
# Mean Reward of that batch 0.0
# Average Reward of all training: 2.443007662835249
# Max reward for a batch so far: 16.0
# Training Loss: -0.38363033533096313
# ==========================================
# Epoch:  175 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 9.0
# Mean Reward of that batch 3.0
# Average Reward of all training: 2.4461904761904765
# Max reward for a batch so far: 16.0
# Training Loss: -0.2129942625761032
# ==========================================
# Epoch:  176 / 1000
# -----------
# Number of training episodes: 2
# Total reward: 9.0
# Mean Reward of that batch 4.5
# Average Reward of all training: 2.4578598484848486
# Max reward for a batch so far: 16.0
# Training Loss: -0.054731231182813644
# ==========================================
# Epoch:  177 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 12.0
# Mean Reward of that batch 4.0
# Average Reward of all training: 2.466572504708098
# Max reward for a batch so far: 16.0
# Training Loss: -0.017177721485495567
# ==========================================
# Epoch:  178 / 1000
# -----------
# Number of training episodes: 2
# Total reward: 11.0
# Mean Reward of that batch 5.5
# Average Reward of all training: 2.483614232209738
# Max reward for a batch so far: 16.0
# Training Loss: 0.07307024300098419
# ==========================================
# Epoch:  179 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 11.0
# Mean Reward of that batch 3.6666666666666665
# Average Reward of all training: 2.4902234636871508
# Max reward for a batch so far: 16.0
# Training Loss: 0.044905293732881546
# ==========================================
# Epoch:  180 / 1000
# -----------
# Number of training episodes: 2
# Total reward: 9.0
# Mean Reward of that batch 4.5
# Average Reward of all training: 2.501388888888889
# Max reward for a batch so far: 16.0
# Training Loss: 0.01864411123096943
# Model saved
# ==========================================
# Epoch:  181 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 11.0
# Mean Reward of that batch 3.6666666666666665
# Average Reward of all training: 2.5078268876611416
# Max reward for a batch so far: 16.0
# Training Loss: -0.006740349344909191
# ==========================================
# Epoch:  182 / 1000
# -----------
# Number of training episodes: 2
# Total reward: 11.0
# Mean Reward of that batch 5.5
# Average Reward of all training: 2.524267399267399
# Max reward for a batch so far: 16.0
# Training Loss: -0.09857701510190964
# ==========================================
# Epoch:  183 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 8.0
# Mean Reward of that batch 2.6666666666666665
# Average Reward of all training: 2.525045537340619
# Max reward for a batch so far: 16.0
# Training Loss: 0.08182816952466965
# ==========================================
# Epoch:  184 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 5.0
# Mean Reward of that batch 1.6666666666666667
# Average Reward of all training: 2.520380434782609
# Max reward for a batch so far: 16.0
# Training Loss: 0.01463815663009882
# ==========================================
# Epoch:  185 / 1000
# -----------
# Number of training episodes: 4
# Total reward: 1.0
# Mean Reward of that batch 0.25
# Average Reward of all training: 2.5081081081081082
# Max reward for a batch so far: 16.0
# Training Loss: -0.09348249435424805
# ==========================================
# Epoch:  186 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 11.0
# Mean Reward of that batch 3.6666666666666665
# Average Reward of all training: 2.514336917562724
# Max reward for a batch so far: 16.0
# Training Loss: -0.039912909269332886
# ==========================================
# Epoch:  187 / 1000
# -----------
# Number of training episodes: 4
# Total reward: 2.0
# Mean Reward of that batch 0.5
# Average Reward of all training: 2.503565062388592
# Max reward for a batch so far: 16.0
# Training Loss: -0.287119597196579
# ==========================================
# Epoch:  188 / 1000
# -----------
# Number of training episodes: 4
# Total reward: 6.0
# Mean Reward of that batch 1.5
# Average Reward of all training: 2.49822695035461
# Max reward for a batch so far: 16.0
# Training Loss: -0.1293388158082962
# ==========================================
# Epoch:  189 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 5.0
# Mean Reward of that batch 1.6666666666666667
# Average Reward of all training: 2.4938271604938276
# Max reward for a batch so far: 16.0
# Training Loss: -0.2738592326641083
# ==========================================
# Epoch:  190 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 11.0
# Mean Reward of that batch 3.6666666666666665
# Average Reward of all training: 2.5
# Max reward for a batch so far: 16.0
# Training Loss: -0.15916721522808075
# Model saved
# ==========================================
# Epoch:  191 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 5.0
# Mean Reward of that batch 1.6666666666666667
# Average Reward of all training: 2.4956369982548
# Max reward for a batch so far: 16.0
# Training Loss: -0.21801255643367767
# ==========================================
# Epoch:  192 / 1000
# -----------
# Number of training episodes: 4
# Total reward: 2.0
# Mean Reward of that batch 0.5
# Average Reward of all training: 2.485243055555556
# Max reward for a batch so far: 16.0
# Training Loss: -0.40828150510787964
# ==========================================
# Epoch:  193 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 10.0
# Mean Reward of that batch 3.3333333333333335
# Average Reward of all training: 2.489637305699482
# Max reward for a batch so far: 16.0
# Training Loss: 0.3734748959541321
# ==========================================
# Epoch:  194 / 1000
# -----------
# Number of training episodes: 4
# Total reward: 7.0
# Mean Reward of that batch 1.75
# Average Reward of all training: 2.4858247422680413
# Max reward for a batch so far: 16.0
# Training Loss: -0.3198924958705902
# ==========================================
# Epoch:  195 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 12.0
# Mean Reward of that batch 4.0
# Average Reward of all training: 2.4935897435897436
# Max reward for a batch so far: 16.0
# Training Loss: 0.002163479570299387
# ==========================================
# Epoch:  196 / 1000
# -----------
# Number of training episodes: 4
# Total reward: 4.0
# Mean Reward of that batch 1.0
# Average Reward of all training: 2.485969387755102
# Max reward for a batch so far: 16.0
# Training Loss: -0.18510764837265015
# ==========================================
# Epoch:  197 / 1000
# -----------
# Number of training episodes: 4
# Total reward: 4.0
# Mean Reward of that batch 1.0
# Average Reward of all training: 2.478426395939086
# Max reward for a batch so far: 16.0
# Training Loss: 0.3698073625564575
# ==========================================
# Epoch:  198 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 1.0
# Mean Reward of that batch 0.3333333333333333
# Average Reward of all training: 2.467592592592593
# Max reward for a batch so far: 16.0
# Training Loss: -1.5780408382415771
# ==========================================
# Epoch:  199 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 12.0
# Mean Reward of that batch 4.0
# Average Reward of all training: 2.4752931323283085
# Max reward for a batch so far: 16.0
# Training Loss: 0.08404528349637985
# ==========================================
# Epoch:  200 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 9.0
# Mean Reward of that batch 3.0
# Average Reward of all training: 2.4779166666666668
# Max reward for a batch so far: 16.0
# Training Loss: 0.454950749874115
# Model saved
# ==========================================
# Epoch:  201 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 10.0
# Mean Reward of that batch 3.3333333333333335
# Average Reward of all training: 2.4821724709784414
# Max reward for a batch so far: 16.0
# Training Loss: 0.2029973864555359
# ==========================================
# Epoch:  202 / 1000
# -----------
# Number of training episodes: 4
# Total reward: 3.0
# Mean Reward of that batch 0.75
# Average Reward of all training: 2.4735973597359737
# Max reward for a batch so far: 16.0
# Training Loss: -0.40899884700775146
# ==========================================
# Epoch:  203 / 1000
# -----------
# Number of training episodes: 2
# Total reward: 10.0
# Mean Reward of that batch 5.0
# Average Reward of all training: 2.486042692939245
# Max reward for a batch so far: 16.0
# Training Loss: -0.6275884509086609
# ==========================================
# Epoch:  204 / 1000
# -----------
# Number of training episodes: 4
# Total reward: 8.0
# Mean Reward of that batch 2.0
# Average Reward of all training: 2.4836601307189543
# Max reward for a batch so far: 16.0
# Training Loss: -0.6803195476531982
# ==========================================
# Epoch:  205 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 11.0
# Mean Reward of that batch 3.6666666666666665
# Average Reward of all training: 2.4894308943089434
# Max reward for a batch so far: 16.0
# Training Loss: 0.4620322585105896
# ==========================================
# Epoch:  206 / 1000
# -----------
# Number of training episodes: 3
# Total reward: 7.0
# Mean Reward of that batch 2.3333333333333335
# Average Reward of all training: 2.4886731391585766
# Max reward for a batch so far: 16.0
# Training Loss: 0.1325663924217224
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-95466a340e0a> in <module>()
#      17     while epoch < num_epochs + 1:
#      18         # Gather training data
# ---> 19         states_mb, actions_mb, rewards_of_batch, discounted_rewards_mb, nb_episodes_mb = make_batch(batch_size, stacked_frames)
#      20
#      21         ### These part is used for analytics
#
# <ipython-input-11-de26d210871d> in make_batch(batch_size, stacked_frames)
#      19         # Run State Through Policy & Calculate Action
#      20         action_probability_distribution = sess.run(PGNetwork.action_distribution,
# ---> 21                                                    feed_dict={PGNetwork.inputs_: state.reshape(1, *state_size)})
#      22
#      23         # REMEMBER THAT WE ARE IN A STOCHASTIC POLICY SO WE DON'T ALWAYS TAKE THE ACTION WITH THE HIGHEST PROBABILITY
#
# ~\Anaconda3\envs\gameplai\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     893     try:
#     894       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 895                          run_metadata_ptr)
#     896       if run_metadata:
#     897         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~\Anaconda3\envs\gameplai\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1126     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1127       results = self._do_run(handle, final_targets, final_fetches,
# -> 1128                              feed_dict_tensor, options, run_metadata)
#    1129     else:
#    1130       results = []
#
# ~\Anaconda3\envs\gameplai\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1342     if handle is None:
#    1343       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1344                            options, run_metadata)
#    1345     else:
#    1346       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# ~\Anaconda3\envs\gameplai\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1348   def _do_call(self, fn, *args):
#    1349     try:
# -> 1350       return fn(*args)
#    1351     except errors.OpError as e:
#    1352       message = compat.as_text(e.message)
#
# ~\Anaconda3\envs\gameplai\lib\site-packages\tensorflow\python\client\session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1327           return tf_session.TF_Run(session, options,
#    1328                                    feed_dict, fetch_list, target_list,
# -> 1329                                    status, run_metadata)
#    1330
#    1331     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %% [markdown]
# ## Step 8: Watch our Agent play 👀
# Now that we trained our agent, we can test it

# %%
# Saver
saver = tf.train.Saver()

with tf.Session() as sess:
    game = DoomGame()

    # Load the correct configuration 
    game.load_config("defend_the_center.cfg")
    
    # Load the correct scenario (in our case basic scenario)
    game.set_doom_scenario_path("defend_the_center.wad")
    
    # Load the model
    saver.restore(sess, "./models/model.ckpt")
    game.init()
    
    for i in range(10):
        
        # Launch a new episode
        game.new_episode()

        # Get a new state
        state = game.get_state().screen_buffer
        state, stacked_frames = stack_frames(stacked_frames, state, True)

        while not game.is_episode_finished():
        
            # Run State Through Policy & Calculate Action
            action_probability_distribution = sess.run(PGNetwork.action_distribution, 
                                                       feed_dict={PGNetwork.inputs_: state.reshape(1, *state_size)})

            # REMEMBER THAT WE ARE IN A STOCHASTIC POLICY SO WE DON'T ALWAYS TAKE THE ACTION WITH THE HIGHEST PROBABILITY
            # (For instance if the action with the best probability for state S is a1 with 70% chances, there is
            #30% chance that we take action a2)
            action = np.random.choice(range(action_probability_distribution.shape[1]), 
                                      p=action_probability_distribution.ravel())  # select action w.r.t the actions prob
            action = possible_actions[action]

            # Perform action
            reward = game.make_action(action)
            done = game.is_episode_finished()
            
            if done:
                break
            else:
                # If not done, the next_state become the current state
                next_state = game.get_state().screen_buffer
                next_state, stacked_frames = stack_frames(stacked_frames, next_state, False)
                state = next_state
        

        print("Score for episode ", i, " :", game.get_total_reward())
    game.close()
# Out:
# INFO:tensorflow:Restoring parameters from ./models/model.ckpt
# Score for episode  0  : 2.0
# Score for episode  1  : 3.0
# Score for episode  2  : 6.0
# Score for episode  3  : 2.0
# Score for episode  4  : 3.0
# Score for episode  5  : 2.0
# Score for episode  6  : 3.0
# Score for episode  7  : 2.0
# Score for episode  8  : 4.0
# Score for episode  9  : 6.0
